# %%
# !brew install wget
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 2 taps (homebrew/core and homebrew/cask).
# ==> New Formulae
# bindgen                    libretls                   python-lsp-server
# btrfs-progs                libunibreak                python-tk@3.11
# cdsclient                  license-eye                python@3.11
# cloudprober                llama                      rnr
# cmctl                      macpine                    ruff
# cntb                       mariadb@10.8               socket_vmnet
# conda-zsh-completion       mariadb@10.9               tart
# corrosion                  markdownlint-cli2          temporal
# d2                         muon                       textract
# ferium                     node@18                    trezor-bridge
# graphqxl                   pandemics                  tut
# hotbuild                   pbzx                       typewritten
# huggingface-cli            pferd                      typos-cli
# hysteria                   pgsync                     valijson
# joker                      pinocchio                  vhs
# kubevious                  pluto                      waybackpy
# kustomizer                 pomsky                     xcodes
# libdivide                  postgresql@15              xq
# libemf2svg                 proxsuite
# libgrapheme                python-gdbm@3.11
# ==> New Casks
# 86box                                    openlens
# adze                                     opensoundmeter
# ankerslicer                              paper
# anytype                                  picfindr
# arc                                      pieces-cli
# ares                                     planet
# binocs                                   prismlauncher
# blurscreen                               protonmail-import-export
# buzz                                     quiet-reader
# cad-assistant                            rapidapi
# chipmunk                                 readmoreading
# clickshare                               reflex
# color-studio                             restfox
# dbeaverlite                              slab
# dbeaverultimate                          slack-cli
# eloquent                                 sms-plus
# faxbot                                   superkey
# finch                                    tageditor
# fleet                                    tempbox
# genesis-plus                             thangs-sync
# go-shiori                                topaz-denoise-ai
# hookmark                                 topaz-gigapixel-ai
# icon-shelf                               topaz-sharpen-ai
# kigb                                     topaz-video-ai
# kopiaui                                  unite-phone
# mixin                                    watchfacestudio
# neat                                     wolfram-engine
# northern-softworks-cache-cleaner         workspace-one-intelligent-hub
# onekey
#
# You have 15 outdated formulae installed.
# You can upgrade them with brew upgrade
# or list them with brew outdated.
#
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/manifests/0.21.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gettext/blobs/sha256:9318777367
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/manifests/1.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libunistring/blobs/sha256:18a16
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/manifests/2.3.4
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libidn2/blobs/sha256:335207a9dc
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/manifests/2022-
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ca-certificates/blobs/sha256:1b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/manifests/1.1.1s
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openssl/1.1/blobs/sha256:d91517
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/manifests/1.21.3
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/wget/blobs/sha256:aa706c58ae7e9
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Installing dependencies for wget: gettext, libunistring, libidn2, ca-certificates and openssl@1.1
# ==> Installing wget dependency: gettext
# ==> Pouring gettext--0.21.1.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/gettext/0.21.1: 1,983 files, 20.6MB
# ==> Installing wget dependency: libunistring
# ==> Pouring libunistring--1.0.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libunistring/1.0: 56 files, 5MB
# ==> Installing wget dependency: libidn2
# ==> Pouring libidn2--2.3.4.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/libidn2/2.3.4: 79 files, 1.2MB
# ==> Installing wget dependency: ca-certificates
# ==> Pouring ca-certificates--2022-10-11.all.bottle.tar.gz
# ==> Regenerating CA certificate bundle from keychain, this may take a while...
# 🍺  /usr/local/Cellar/ca-certificates/2022-10-11: 3 files, 225.5KB
# ==> Installing wget dependency: openssl@1.1
# ==> Pouring openssl@1.1--1.1.1s.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/openssl@1.1/1.1.1s: 8,101 files, 18.5MB
# ==> Installing wget
# ==> Pouring wget--1.21.3.monterey.bottle.tar.gz
# 🍺  /usr/local/Cellar/wget/1.21.3: 89 files, 4.2MB
# ==> Running `brew cleanup wget`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading 4 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# node 18.0.0 -> 19.2.0, jupyterlab 3.3.2 -> 3.4.8, pyenv 2.2.5 -> 2.3.7, python@3.9 3.9.12 -> 3.9.15
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/manifests/71.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/icu4c/blobs/sha256:87617a04333c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.51.0-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:d94c9ee
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/manifests/1.44.2-1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libuv/blobs/sha256:ccef3d8ae217
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/manifests/19.2.0
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/blobs/sha256:d4dcb22958f6d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pygments/manifests/2.13.0_1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pygments/blobs/sha256:4c44f5496
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/manifests/8.2.1
# ######################################################################## 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/readline/blobs/sha256:19e6b02f5
# ^C

# %%
# !wget "https://aicore-files.s3.amazonaws.com/Foundations/Software_Engineering/testing_example.zip"
# Out:
# --2022-12-04 12:35:57--  https://aicore-files.s3.amazonaws.com/Foundations/Software_Engineering/testing_example.zip
# Resolving aicore-files.s3.amazonaws.com (aicore-files.s3.amazonaws.com)... 52.216.28.148, 3.5.11.146, 52.216.32.57, ...
# Connecting to aicore-files.s3.amazonaws.com (aicore-files.s3.amazonaws.com)|52.216.28.148|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2791 (2,7K) [application/zip]
# Saving to: ‘testing_example.zip’
#
# testing_example.zip 100%[===================>]   2,73K  --.-KB/s    in 0,002s
#
# 2022-12-04 12:35:58 (1,52 MB/s) - ‘testing_example.zip’ saved [2791/2791]

# %%
#!wget "https://aicore-files.s3.amazonaws.com/Foundations/Software_Engineering/testing_example.zip"
import zipfile

with zipfile.ZipFile("testing_example.zip", 'r') as zip_ref:
    zip_ref.extractall("testing_example")
# !cp -r testing_example/example .
